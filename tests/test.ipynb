# %%
import pandas as pd

df = pd.read_parquet("D:/civicgpt_stack/airflow/data/processed/2025-07-12.parquet")
(df.head())
# Out:
#                                  id  \
# 0  1bd887313fcf546d0090bec9e5e1f888
# 1  afcad3d84a5148098795b0e407b94abc
# 2  f4fe83d89348913d7c49fb979394e82f
# 3  c2940ea26e0227efdf6bd8d79f8b47c6
# 4  696ca98fe1ec155c62f87139518b7722
#
#                                                 link  \
# 0  https://www.cbc.ca/news/canada/toronto/souther...
# 1  https://www.cbc.ca/news/canada/toronto/trump-s...
# 2  https://www.cbc.ca/news/canada/kitchener-water...
# 3   https://www.cbc.ca/player/play/9.6828332?cmp=rss
# 4  https://www.cbc.ca/news/canada/toronto/ontario...
#
#                        published  \
# 0  Fri, 11 Jul 2025 13:00:17 EDT
# 1  Fri, 11 Jul 2025 14:00:43 EDT
# 2  Fri, 11 Jul 2025 08:00:00 EDT
# 3  Fri, 11 Jul 2025 10:42:12 EDT
# 4  Fri, 11 Jul 2025 13:41:43 EDT
#
#                                               source  \
# 0  http://rss.cbc.ca/lineup/canada-kitchenerwater...
# 1  http://rss.cbc.ca/lineup/canada-kitchenerwater...
# ...
